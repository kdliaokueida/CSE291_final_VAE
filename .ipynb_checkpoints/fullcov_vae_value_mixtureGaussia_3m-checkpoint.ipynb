# %%
import torch
import torch.nn.functional as nn
import torch.autograd as autograd
import torch.optim as optim
from torch.distributions.multivariate_normal import MultivariateNormal
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
import math
from torch.autograd import Variable

# %%
N=60000
U = np.random.uniform(0,1,N)
X1 = np.random.multivariate_normal([0, 3*math.sqrt(3)], [[3, 0], [0, 1/3]], 60000)
X2 = np.random.multivariate_normal([0,0], [[3, 0], [0, 1/3]], 60000)
X3 = np.random.multivariate_normal([0,0], [[3, 0], [0, 1/3]], 60000)
A = [[np.cos(np.pi*2/3), -np.sin(np.pi*2/3)],[np.sin(np.pi*2/3), np.cos(np.pi*2/3)]]
B = [[np.cos(np.pi/3), -np.sin(np.pi/3)],[np.sin(np.pi/3), np.cos(np.pi/3)]]
X2 = np.matmul(A, X2.transpose()).transpose() + [-3*math.sqrt(3), -3*math.sqrt(3)/2]
X3 = np.matmul(B, X3.transpose()).transpose() + [3*math.sqrt(3), -3*math.sqrt(3)/2]

X = np.zeros((40000,2))
for i in range(40000):
    if U[i]<1/3:
        X[i] = X1[i]
    elif U[i]<2/3:
        X[i] = X2[i]
    else:
        X[i] = X3[i]
        
X_test = np.zeros((20000,2))
for i in range(40000,60000):
    if U[i]<1/3:
        X_test[i-40000] = X1[i]
    elif U[i]<2/3:
        X_test[i-40000] = X2[i]
    else:
        X_test[i-40000] = X3[i]

# %%
plt.hist2d(X[:,0],X[:,1],bins=50,cmap="gist_heat_r")
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.savefig('sigma2_gaussianmixture_2d_fullcov_3m/gm_training.png')

# %%
mb_size = 64
Z_dim = 2
X_dim = X.shape[1]
h_dim = 128
c = 0
lr = 1e-5

def xavier_init(size):
    in_dim = size[0]
    xavier_stddev = 1. / np.sqrt(in_dim / 2.)
    return Variable(torch.randn(*size) * xavier_stddev, requires_grad=True)

# %%
# =============================== Q(z|X) ======================================

Wxh = xavier_init(size=[X_dim, h_dim])
bxh = Variable(torch.zeros(h_dim), requires_grad=True)

Whz_mu = xavier_init(size=[h_dim, Z_dim])
bhz_mu = Variable(torch.zeros(Z_dim), requires_grad=True)

Whz_var = xavier_init(size=[h_dim, Z_dim])
bhz_var = Variable(torch.zeros(Z_dim), requires_grad=True)

tri_idx_row, tri_idx_col = torch.tril_indices(row=Z_dim, col=Z_dim)
tri_idx = (tri_idx_row != tri_idx_col)  # Delete diagonal
tri_idx_row = tri_idx_row[tri_idx]
tri_idx_col = tri_idx_col[tri_idx]

Whz_L = xavier_init(size=[h_dim, len(tri_idx_col)])  # cholesky of cov
bhz_L = Variable(torch.zeros(len(tri_idx_col)), requires_grad=True)

def Q(X):
    h = nn.relu(X @ Wxh + bxh.repeat(X.size(0), 1))
    z_mu = h @ Whz_mu + bhz_mu.repeat(h.size(0), 1)
    z_logvar = h @ Whz_var + bhz_var.repeat(h.size(0), 1)
    z_L = h @ Whz_L + bhz_L.repeat(h.size(0), 1)
    return z_mu, z_logvar, z_L


# ============================ Reparameterization and Sample =============================

def sample_z(mu, log_var, L_):
    
    device = mu.device
    batch_size = mu.shape[0]
    
#     log_var = torch.clamp(log_var, max=10)
    L = torch.zeros(batch_size, Z_dim, Z_dim, device=device)
    L[:, tri_idx_row, tri_idx_col] = L_
    L += torch.diag_embed(torch.exp(log_var))  # Diagonal matrix for batch
    
    # sample noise from multivariate Gaussain
    eps = torch.randn(mu.shape[0], Z_dim, device=device)
    
    # Use batchwise matrix multiplication
    sample = mu + torch.bmm(L, eps.unsqueeze(-1)).squeeze()
    
    return eps, sample

# %%
# =============================== P(X|z) ======================================

Wzh = xavier_init(size=[Z_dim, h_dim])
bzh = Variable(torch.zeros(h_dim), requires_grad=True)

Whmu = xavier_init(size=[h_dim, X_dim])
bhmu = Variable(torch.zeros(X_dim), requires_grad=True)

Whsigma = xavier_init(size=[h_dim, X_dim])
bhsigma = Variable(torch.zeros(X_dim), requires_grad=True)

Whsigma = xavier_init(size=[h_dim, X_dim])
bhsigma = Variable(torch.zeros(X_dim), requires_grad=True)

Xtri_idx_row, Xtri_idx_col = torch.tril_indices(row=X_dim, col=X_dim)
Xtri_idx = (Xtri_idx_row != Xtri_idx_col)  # Delete diagonal
Xtri_idx_row = Xtri_idx_row[Xtri_idx]
Xtri_idx_col = Xtri_idx_col[Xtri_idx]

Whx_L = xavier_init(size=[h_dim, len(Xtri_idx_col)])  # cholesky of cov
bhx_L = Variable(torch.zeros(len(Xtri_idx_col)), requires_grad=True)

def P(z):
    h = torch.tanh(z @ Wzh + bzh.repeat(z.size(0), 1))
    X_mu = (h @ Whmu + bhmu.repeat(h.size(0), 1))
    X_log_var = (h @ Whsigma + bhsigma.repeat(h.size(0), 1))
    X_L = h @ Whx_L + bhx_L.repeat(h.size(0), 1)
    
    
    return X_mu, X_log_var, X_L

def X_full(log_var, L_):
    
    device = log_var.device
    batch_size = log_var.shape[0]
    
    L = torch.zeros(batch_size, X_dim, X_dim, device=device)
    L[:, Xtri_idx_row, Xtri_idx_col] = L_
    L += torch.diag_embed(torch.exp(log_var))  # Diagonal matrix for batch
    
    return torch.bmm(L, torch.transpose(L,1,2))

# %%
from torch.utils.data import Dataset, DataLoader

class MyDataset(Dataset):
    def __init__(self, data, target, transform=None):
        self.data = torch.from_numpy(data).float()
        self.data = torch.flatten(self.data, start_dim=1)
        self.target = torch.from_numpy(target).float()
        self.transform = transform
        
    def __getitem__(self, index):
        x = self.data[index]
        y = self.target[index]
        
        if self.transform:
            x = self.transform(x)
        
        return x, y
    
    def __len__(self):
        return len(self.data)

# %%
dataset = MyDataset(X, X)
loader = DataLoader(
    dataset,
    batch_size=mb_size,
    shuffle=True,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

# for batch_idx, (data, target) in enumerate(loader):
#     print('Batch idx {}, data shape {}, target shape {}'.format(
#         batch_idx, data.shape, target.shape))

# %%
# =============================== TRAINING ====================================

params = [Wxh, bxh, Whz_mu, bhz_mu, Whz_var, bhz_var, Whz_L, bhz_L,
          Wzh, bzh, Whmu, bhmu, Whsigma, bhsigma, Whx_L, bhx_L]

solver = optim.Adam(params, lr=lr)

loss_epoch = []
x_from_prior = []
x_from_test = []

Z = torch.Tensor(np.random.multivariate_normal([0,0], [[1,0],[0,1]], 2*10**4))
X_sample_mu, X_sample_logvar, X_sample_L = P(Z)
X_sample_sigma = X_full(X_sample_logvar, X_sample_L)
kernels = MultivariateNormal(X_sample_mu, X_sample_sigma)

x_from_prior.append(kernels.sample().cpu().detach().numpy())

test_data = torch.from_numpy(X_test).float()
Z_mu, Z_logvar, Z_L = Q(test_data)
_, Z = sample_z(Z_mu, Z_logvar, Z_L)
X_sample_mu, X_sample_logvar, X_sample_L = P(Z)
X_sample_sigma = X_full(X_sample_logvar, X_sample_L)
kernels = MultivariateNormal(X_sample_mu, X_sample_sigma)

x_from_test.append(kernels.sample().cpu().detach().numpy())
            
for it in range(400):
    for x_batch, y_batch in loader:
        
        # Forward
        z_mu, z_logvar, z_L = Q(x_batch)
        eps, z = sample_z(z_mu, z_logvar, z_L)
        x_sample_mu, x_sample_logvar, x_sample_L = P(z)
        x_sample_sigma = X_full(x_sample_logvar, x_sample_L)

        # Loss
        #recon_loss = nn.binary_cross_entropy(x_sample, x_batch, size_average=False) / mb_size  # Bernoulli
#         x_sample_sigma_square = torch.diag_embed(torch.exp(x_sample_logvar), dim1=-2, dim2=-1)
        kernels = MultivariateNormal(x_sample_mu, x_sample_sigma)
#         recon_loss = kernels.log_prob(x_batch[:,None,:]).mean()
        log_px_loss = -1*kernels.log_prob(x_batch).mean()
        log_qz = -torch.sum(.5*(eps**2 + math.log(2 * math.pi) + 2*z_logvar), -1)
        log_pz = -torch.sum(.5*(z**2 + math.log(2*math.pi)), -1)
        
        loss = log_px_loss - torch.mean(log_pz) + torch.mean(log_qz)

        # Backward
        loss.backward()

        # Update
        solver.step()

        # Housekeeping
        for p in params:
            if p.grad is not None:
                data = p.grad.data
                p.grad = Variable(data.new().resize_as_(data).zero_())
                

    # Print loss after each epoch
    loss_epoch.append(loss.item())
    print('Iter-{}; Loss: {:.4}'.format(it+1, loss.item()))

    # generate samples
    Z = torch.Tensor(np.random.multivariate_normal([0,0], [[1,0],[0,1]], 2*10**4))
    X_sample_mu, X_sample_logvar, X_sample_L = P(Z)
    X_sample_sigma = X_full(X_sample_logvar, X_sample_L)
    kernels = MultivariateNormal(X_sample_mu, X_sample_sigma)

    x_from_prior.append(kernels.sample().cpu().detach().numpy())

    test_data = torch.from_numpy(X_test).float()
    Z_mu, Z_logvar, Z_L = Q(test_data)
    _, Z = sample_z(Z_mu, Z_logvar, Z_L)
    X_sample_mu, X_sample_logvar, X_sample_L = P(Z)
    X_sample_sigma = X_full(X_sample_logvar, X_sample_L)
    kernels = MultivariateNormal(X_sample_mu, X_sample_sigma)

    x_from_test.append(kernels.sample().cpu().detach().numpy())
# Out:
# Iter-1; Loss: 368.5
# Iter-2; Loss: 125.3
# Iter-3; Loss: 98.59
# Iter-4; Loss: 108.5
# Iter-5; Loss: 87.22
# Iter-6; Loss: 67.16
# Iter-7; Loss: 74.25
# Iter-8; Loss: 53.59
# Iter-9; Loss: 66.14
# Iter-10; Loss: 45.82
# Iter-11; Loss: 36.73
# Iter-12; Loss: 25.42
# Iter-13; Loss: 27.0
# Iter-14; Loss: 22.58
# Iter-15; Loss: 19.14
# Iter-16; Loss: 20.66
# Iter-17; Loss: 12.65
# Iter-18; Loss: 14.64
# Iter-19; Loss: 12.32
# Iter-20; Loss: 10.94
# Iter-21; Loss: 10.18
# Iter-22; Loss: 9.543
# Iter-23; Loss: 8.732
# Iter-24; Loss: 8.494
# Iter-25; Loss: 8.346
# Iter-26; Loss: 7.667
# Iter-27; Loss: 7.481
# Iter-28; Loss: 7.619
# Iter-29; Loss: 7.145
# Iter-30; Loss: 7.01
# Iter-31; Loss: 7.283
# Iter-32; Loss: 7.048
# Iter-33; Loss: 6.638
# Iter-34; Loss: 6.73
# Iter-35; Loss: 6.791
# Iter-36; Loss: 6.567
# Iter-37; Loss: 6.743
# Iter-38; Loss: 6.482
# Iter-39; Loss: 6.398
# Iter-40; Loss: 6.324
# Iter-41; Loss: 6.387
# Iter-42; Loss: 6.042
# Iter-43; Loss: 5.797
# Iter-44; Loss: 6.007
# Iter-45; Loss: 6.028
# Iter-46; Loss: 5.819
# Iter-47; Loss: 5.819
# Iter-48; Loss: 5.548
# Iter-49; Loss: 5.725
# Iter-50; Loss: 5.7
# Iter-51; Loss: 5.446
# Iter-52; Loss: 5.578
# Iter-53; Loss: 5.541
# Iter-54; Loss: 5.472
# Iter-55; Loss: 5.475
# Iter-56; Loss: 5.332
# Iter-57; Loss: 5.416
# Iter-58; Loss: 5.421
# Iter-59; Loss: 5.524
# Iter-60; Loss: 5.561
# Iter-61; Loss: 5.321
# Iter-62; Loss: 5.537
# Iter-63; Loss: 5.271
# Iter-64; Loss: 5.365
# Iter-65; Loss: 5.107
# Iter-66; Loss: 5.251
# Iter-67; Loss: 5.299
# Iter-68; Loss: 5.318
# Iter-69; Loss: 5.369
# Iter-70; Loss: 5.122
# Iter-71; Loss: 5.151
# Iter-72; Loss: 5.141
# Iter-73; Loss: 4.928
# Iter-74; Loss: 5.057
# Iter-75; Loss: 5.053
# Iter-76; Loss: 5.387
# Iter-77; Loss: 5.199
# Iter-78; Loss: 5.162
# Iter-79; Loss: 5.175
# Iter-80; Loss: 5.069
# Iter-81; Loss: 5.023
# Iter-82; Loss: 5.132
# Iter-83; Loss: 4.978
# Iter-84; Loss: 5.101
# Iter-85; Loss: 5.003
# Iter-86; Loss: 5.005
# Iter-87; Loss: 4.947
# Iter-88; Loss: 5.143
# Iter-89; Loss: 4.925
# Iter-90; Loss: 5.053
# Iter-91; Loss: 5.167
# Iter-92; Loss: 4.852
# Iter-93; Loss: 4.956
# Iter-94; Loss: 5.036
# Iter-95; Loss: 4.992
# Iter-96; Loss: 4.869
# Iter-97; Loss: 5.056
# Iter-98; Loss: 4.966
# Iter-99; Loss: 4.977
# Iter-100; Loss: 4.866
# Iter-101; Loss: 4.936
# Iter-102; Loss: 4.98
# Iter-103; Loss: 5.06
# Iter-104; Loss: 5.071
# Iter-105; Loss: 4.981
# Iter-106; Loss: 4.85
# Iter-107; Loss: 5.022
# Iter-108; Loss: 4.903
# Iter-109; Loss: 4.816
# Iter-110; Loss: 4.977
# Iter-111; Loss: 4.88
# Iter-112; Loss: 4.665
# Iter-113; Loss: 5.004
# Iter-114; Loss: 4.965
# Iter-115; Loss: 5.031
# Iter-116; Loss: 4.816
# Iter-117; Loss: 4.862
# Iter-118; Loss: 4.826
# Iter-119; Loss: 4.844
# Iter-120; Loss: 4.706
# Iter-121; Loss: 4.959
# Iter-122; Loss: 4.809
# Iter-123; Loss: 5.026
# Iter-124; Loss: 4.789
# Iter-125; Loss: 4.928
# Iter-126; Loss: 5.102
# Iter-127; Loss: 4.727
# Iter-128; Loss: 4.958
# Iter-129; Loss: 4.807
# Iter-130; Loss: 4.872
# Iter-131; Loss: 4.938
# Iter-132; Loss: 4.762
# Iter-133; Loss: 4.993
# Iter-134; Loss: 4.76
# Iter-135; Loss: 4.863
# Iter-136; Loss: 4.784
# Iter-137; Loss: 4.855
# Iter-138; Loss: 4.868
# Iter-139; Loss: 4.724
# Iter-140; Loss: 4.918
# Iter-141; Loss: 4.756
# Iter-142; Loss: 4.774
# Iter-143; Loss: 4.68
# Iter-144; Loss: 4.72
# Iter-145; Loss: 4.795
# Iter-146; Loss: 4.702
# Iter-147; Loss: 5.03
# Iter-148; Loss: 4.87
# Iter-149; Loss: 4.832
# Iter-150; Loss: 5.013
# Iter-151; Loss: 4.765
# Iter-152; Loss: 4.74
# Iter-153; Loss: 4.832
# Iter-154; Loss: 4.92
# Iter-155; Loss: 4.935
# Iter-156; Loss: 4.652
# Iter-157; Loss: 4.717
# Iter-158; Loss: 5.132
# Iter-159; Loss: 4.991
# Iter-160; Loss: 4.711
# Iter-161; Loss: 4.807
# Iter-162; Loss: 4.977
# Iter-163; Loss: 4.688
# Iter-164; Loss: 4.773
# Iter-165; Loss: 4.706
# Iter-166; Loss: 4.717
# Iter-167; Loss: 4.828
# Iter-168; Loss: 4.947
# Iter-169; Loss: 4.625
# Iter-170; Loss: 4.908
# Iter-171; Loss: 4.725
# Iter-172; Loss: 4.799
# Iter-173; Loss: 4.76
# Iter-174; Loss: 4.824
# Iter-175; Loss: 4.729
# Iter-176; Loss: 4.699
# Iter-177; Loss: 4.826
# Iter-178; Loss: 4.649
# Iter-179; Loss: 4.714
# Iter-180; Loss: 4.764
# Iter-181; Loss: 4.794
# Iter-182; Loss: 4.769
# Iter-183; Loss: 4.708
# Iter-184; Loss: 4.765
# Iter-185; Loss: 4.787
# Iter-186; Loss: 4.815
# Iter-187; Loss: 4.69
# Iter-188; Loss: 4.678
# Iter-189; Loss: 5.149
# Iter-190; Loss: 4.52
# Iter-191; Loss: 4.691
# Iter-192; Loss: 4.71
# Iter-193; Loss: 4.726
# Iter-194; Loss: 4.83
# Iter-195; Loss: 4.76
# Iter-196; Loss: 4.768
# Iter-197; Loss: 4.728
# Iter-198; Loss: 4.759
# Iter-199; Loss: 4.942
# Iter-200; Loss: 4.535
# Iter-201; Loss: 4.66
# Iter-202; Loss: 4.807
# Iter-203; Loss: 4.631
# Iter-204; Loss: 4.592
# Iter-205; Loss: 4.688
# Iter-206; Loss: 4.612
# Iter-207; Loss: 4.655
# Iter-208; Loss: 4.744
# Iter-209; Loss: 4.957
# Iter-210; Loss: 4.725
# Iter-211; Loss: 4.809
# Iter-212; Loss: 5.081
# Iter-213; Loss: 4.986
# Iter-214; Loss: 4.618
# Iter-215; Loss: 4.638
# Iter-216; Loss: 4.574
# Iter-217; Loss: 4.602
# Iter-218; Loss: 4.893
# Iter-219; Loss: 4.892
# Iter-220; Loss: 4.953
# Iter-221; Loss: 4.68
# Iter-222; Loss: 4.758
# Iter-223; Loss: 4.697
# Iter-224; Loss: 4.728
# Iter-225; Loss: 4.648
# Iter-226; Loss: 4.71
# Iter-227; Loss: 4.484
# Iter-228; Loss: 4.732
# Iter-229; Loss: 4.521
# Iter-230; Loss: 4.627
# Iter-231; Loss: 4.66
# Iter-232; Loss: 4.594
# Iter-233; Loss: 4.701
# Iter-234; Loss: 4.689
# Iter-235; Loss: 4.509
# Iter-236; Loss: 4.864
# Iter-237; Loss: 4.849
# Iter-238; Loss: 4.659
# Iter-239; Loss: 4.73
# Iter-240; Loss: 4.466
# Iter-241; Loss: 4.811
# Iter-242; Loss: 4.702
# Iter-243; Loss: 4.765
# Iter-244; Loss: 5.254
# Iter-245; Loss: 4.723
# Iter-246; Loss: 4.691
# Iter-247; Loss: 4.604
# Iter-248; Loss: 4.599
# Iter-249; Loss: 4.754
# Iter-250; Loss: 4.721
# Iter-251; Loss: 4.766
# Iter-252; Loss: 4.677
# Iter-253; Loss: 4.752
# Iter-254; Loss: 4.736
# Iter-255; Loss: 4.511
# Iter-256; Loss: 4.871
# Iter-257; Loss: 4.736
# Iter-258; Loss: 4.586
# Iter-259; Loss: 4.9
# Iter-260; Loss: 4.482
# Iter-261; Loss: 4.631
# Iter-262; Loss: 4.689
# Iter-263; Loss: 5.002
# Iter-264; Loss: 4.734
# Iter-265; Loss: 4.867
# Iter-266; Loss: 4.886
# Iter-267; Loss: 4.661
# Iter-268; Loss: 5.049
# Iter-269; Loss: 4.504
# Iter-270; Loss: 4.751
# Iter-271; Loss: 4.906
# Iter-272; Loss: 4.759
# Iter-273; Loss: 4.467
# Iter-274; Loss: 4.962
# Iter-275; Loss: 4.691
# Iter-276; Loss: 4.575
# Iter-277; Loss: 4.812
# Iter-278; Loss: 4.695
# Iter-279; Loss: 4.58
# Iter-280; Loss: 4.621
# Iter-281; Loss: 4.406
# Iter-282; Loss: 4.771
# Iter-283; Loss: 4.924
# Iter-284; Loss: 4.557
# Iter-285; Loss: 4.594
# Iter-286; Loss: 4.851
# Iter-287; Loss: 4.572
# Iter-288; Loss: 4.526
# Iter-289; Loss: 4.461
# Iter-290; Loss: 4.708
# Iter-291; Loss: 4.513
# Iter-292; Loss: 4.497
# Iter-293; Loss: 4.585
# Iter-294; Loss: 4.642
# Iter-295; Loss: 4.616
# Iter-296; Loss: 4.577
# Iter-297; Loss: 4.63
# Iter-298; Loss: 4.417
# Iter-299; Loss: 4.308
# Iter-300; Loss: 4.695
# Iter-301; Loss: 4.57
# Iter-302; Loss: 4.649
# Iter-303; Loss: 4.779
# Iter-304; Loss: 4.361
# Iter-305; Loss: 4.618
# Iter-306; Loss: 4.639
# Iter-307; Loss: 4.841
# Iter-308; Loss: 4.859
# Iter-309; Loss: 4.979
# Iter-310; Loss: 4.733
# Iter-311; Loss: 4.479
# Iter-312; Loss: 4.558
# Iter-313; Loss: 4.758
# Iter-314; Loss: 4.614
# Iter-315; Loss: 4.574
# Iter-316; Loss: 4.602
# Iter-317; Loss: 4.499
# Iter-318; Loss: 4.416
# Iter-319; Loss: 4.812
# Iter-320; Loss: 4.727
# Iter-321; Loss: 4.404
# Iter-322; Loss: 4.68
# Iter-323; Loss: 4.656
# Iter-324; Loss: 4.727
# Iter-325; Loss: 4.607
# Iter-326; Loss: 4.53
# Iter-327; Loss: 4.357
# Iter-328; Loss: 4.511
# Iter-329; Loss: 4.522
# Iter-330; Loss: 4.604
# Iter-331; Loss: 4.466
# Iter-332; Loss: 4.573
# Iter-333; Loss: 4.531
# Iter-334; Loss: 5.168
# Iter-335; Loss: 4.539
# Iter-336; Loss: 4.704
# Iter-337; Loss: 4.486
# Iter-338; Loss: 4.495
# Iter-339; Loss: 4.716
# Iter-340; Loss: 4.639
# Iter-341; Loss: 4.55
# Iter-342; Loss: 4.573
# Iter-343; Loss: 4.621
# Iter-344; Loss: 4.548
# Iter-345; Loss: 4.593
# Iter-346; Loss: 4.626
# Iter-347; Loss: 4.586
# Iter-348; Loss: 4.624
# Iter-349; Loss: 4.558
# Iter-350; Loss: 4.706
# Iter-351; Loss: 5.118
# Iter-352; Loss: 4.548
# Iter-353; Loss: 4.609
# Iter-354; Loss: 4.503
# Iter-355; Loss: 4.447
# Iter-356; Loss: 4.802
# Iter-357; Loss: 4.485
# Iter-358; Loss: 4.545
# Iter-359; Loss: 4.568
# Iter-360; Loss: 4.779
# Iter-361; Loss: 4.645
# Iter-362; Loss: 4.578
# Iter-363; Loss: 4.323
# Iter-364; Loss: 4.495
# Iter-365; Loss: 4.696
# Iter-366; Loss: 4.552
# Iter-367; Loss: 4.663
# Iter-368; Loss: 4.463
# Iter-369; Loss: 4.693
# Iter-370; Loss: 4.485
# Iter-371; Loss: 4.5
# Iter-372; Loss: 4.442
# Iter-373; Loss: 4.414
# Iter-374; Loss: 4.699
# Iter-375; Loss: 4.532
# Iter-376; Loss: 4.744
# Iter-377; Loss: 4.707
# Iter-378; Loss: 4.593
# Iter-379; Loss: 4.721
# Iter-380; Loss: 4.826
# Iter-381; Loss: 4.668
# Iter-382; Loss: 4.583
# Iter-383; Loss: 4.585
# Iter-384; Loss: 4.596
# Iter-385; Loss: 4.577
# Iter-386; Loss: 4.587
# Iter-387; Loss: 4.635
# Iter-388; Loss: 4.595
# Iter-389; Loss: 4.635
# Iter-390; Loss: 4.487
# Iter-391; Loss: 4.416
# Iter-392; Loss: 4.442
# Iter-393; Loss: 4.469
# Iter-394; Loss: 4.507
# Iter-395; Loss: 4.334
# Iter-396; Loss: 4.459
# Iter-397; Loss: 4.609
# Iter-398; Loss: 4.552
# Iter-399; Loss: 4.655
# Iter-400; Loss: 4.47

# %%
np.save('sigma2_gaussianmixture_2d_fullcov_3m/fullcov_gm_loss',loss_epoch)

# %%
plt.plot(np.arange(1,401),loss_epoch)
plt.xlim(1,400)
plt.yscale('log')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.savefig('sigma2_gaussianmixture_2d_fullcov_3m/gm_loss_epoch.png')

# %%
gs = gridspec.GridSpec(1, 2, width_ratios=[1,3])  #wspace=0.35 
ax0 = plt.subplot(gs[0])
ax0.plot(np.arange(1,101),loss_epoch[:100])
ax0.set_xlim(1,100)
ax0.set_yscale('log')
ax0.set_xlabel('epoch')
ax0.set_ylabel('loss')

ax1 = plt.subplot(gs[1])
ax1.plot(np.arange(101,401),loss_epoch[100:])
ax1.set_xlim(101,400)
ax1.set_xlabel('epoch')

plt.savefig('sigma2_gaussianmixture_2d_fullcov_3m/gm_loss_epoch_bypart.png')

# %%
i += 10
plt.hist2d(x_from_prior[i][:,0],x_from_prior[i][:,1],bins=50,cmap="gist_heat_r")
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.title('epoch #'+str((i)))
plt.savefig('sigma2_gaussianmixture_2d_fullcov_3m/gm_from_prior_epoch'+str((i))+'.png')

# %%
plt.hist2d(x_from_test[i][:,0],x_from_test[i][:,1],bins=50,cmap="gist_heat_r")
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.title('epoch #'+str((i)))
plt.savefig('sigma2_gaussianmixture_2d_fullcov_3m/gm_from_test_epoch'+str((i))+'.png')

# %%
plt.hist2d(x_from_prior[-1][:,0],x_from_prior[-1][:,1],bins=50,cmap="gist_heat_r")
plt.xlim(-10,10)
plt.ylim(-10,10)
# plt.title('epoch #'+str((i)))
plt.savefig('sigma2_gaussianmixture_2d_fullcov_3m/gm_from_prior_final_fail.png')

# %%
plt.hist2d(x_from_test[-1][:,0],x_from_test[-1][:,1],bins=50,cmap="gist_heat_r")
plt.xlim(-10,10)
plt.ylim(-10,10)
# plt.title('epoch #'+str((i)))
plt.savefig('sigma2_gaussianmixture_2d_fullcov_3m/gm_from_test_final.png')
